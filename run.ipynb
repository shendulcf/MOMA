# %%
# !python Tiling.py --help
# Out:
# usage: Tiling.py [-h] -i INPUT_FOLDER_PATH -o OUTPUT_FOLDER_PATH
#                  [-s START_AT_IMAGE_NAME] [-r {0,1}] [-op OVERLAP_PERCENTAGE]
#                  [-ws WINDOW_SIZE]
#
# Split a WSI at a specific resolution in a .SVS file into .JPEG tiles.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -i INPUT_FOLDER_PATH, --input_folder_path INPUT_FOLDER_PATH
#                         The path to the input folder.
#   -o OUTPUT_FOLDER_PATH, --output_folder_path OUTPUT_FOLDER_PATH
#                         The path to the output folder. If output folder
#                         doesn't exists at runtime the script will create it.
#   -s START_AT_IMAGE_NAME, --start_at_image_name START_AT_IMAGE_NAME
#                         Resume from a certain filename. Default value is None.
#   -r {0,1}, --resolution_level {0,1}
#                         Resolution level for image to be split. Low level
# ...

# %%
# !python Tiling.py -i dataset -o output
# Out:
# Patch data 0 0 0 256 256
# Tile size for tile number 1:(256, 256)
# Tile 1 / 17557 created
#
#
# Patch data 0 256 0 256 256
# Tile size for tile number 2:(256, 256)
# Tile 2 / 17557 created
#
#
# Patch data 0 512 0 256 256
# Tile size for tile number 3:(256, 256)
# Tile 3 / 17557 created
#
#
# Patch data 0 768 0 256 256
# Tile size for tile number 4:(256, 256)
# Tile 4 / 17557 created
#
#
# Patch data 0 1024 0 256 256
# Tile size for tile number 5:(256, 256)
# Tile 5 / 17557 created
#
#
# Patch data 0 1280 0 256 256
# Tile size for tile number 6:(256, 256)
# Tile 6 / 17557 created
#
#
# Patch data 0 1536 0 256 256
# Tile size for tile number 7:(256, 256)
# Tile 7 / 17557 created
#
#
# Patch data 0 1792 0 256 256
# Tile size for tile number 8:(256, 256)
# Tile 8 / 17557 created
#
#
# Patch data 0 2048 0 256 256
# Tile size for tile number 9:(256, 256)
# Tile 9 / 17557 created
#
#
# Patch data 0 2304 0 256 256
# Tile size for tile number 10:(256, 256)
# Tile 10 / 17557 created
#
#
# ...
